# %% [markdown]
# # **Music popularity prediction**
# #### Walter Sostene Losa - Filippo Finke

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

# %%
# Read the CSV file
df = pd.read_csv('song_data.csv')

# %% [markdown]
# ## 1. Dataset description

# %%
# Print null values
print(df.isnull().sum())
# Out:
# song_name           0
# song_popularity     0
# song_duration_ms    0
# acousticness        0
# danceability        0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# audio_mode          0
# speechiness         0
# tempo               0
# time_signature      0
# audio_valence       0
# dtype: int64

# %%
# Display the first few rows of the DataFrame
df.head()
# Out:
#                     song_name  song_popularity  song_duration_ms  \
# 0  Boulevard of Broken Dreams               73            262333
# 1                  In The End               66            216933
# 2           Seven Nation Army               76            231733
# 3                  By The Way               74            216933
# 4           How You Remind Me               56            223826
#
#    acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0      0.005520         0.496   0.682          0.000029    8    0.0589
# 1      0.010300         0.542   0.853          0.000000    3    0.1080
# 2      0.008170         0.737   0.463          0.447000    0    0.2550
# 3      0.026400         0.451   0.970          0.003550    0    0.1020
# 4      0.000954         0.447   0.766          0.000000   10    0.1130
#
#    loudness  audio_mode  speechiness    tempo  time_signature  audio_valence
# 0    -4.095           1       0.0294  167.060               4          0.474
# 1    -6.407           0       0.0498  105.256               4          0.370
# 2    -7.828           1       0.0792  123.881               4          0.324
# 3    -4.938           1       0.1070  122.444               4          0.198
# 4    -5.065           1       0.0313  172.011               4          0.574

# %%
# Describe the DataFrame
df.describe()
# Out:
#        song_popularity  song_duration_ms  acousticness  danceability  \
# count     18835.000000      1.883500e+04  18835.000000  18835.000000
# mean         52.991877      2.182116e+05      0.258539      0.633348
# std          21.905654      5.988754e+04      0.288719      0.156723
# min           0.000000      1.200000e+04      0.000001      0.000000
# 25%          40.000000      1.843395e+05      0.024100      0.533000
# 50%          56.000000      2.113060e+05      0.132000      0.645000
# 75%          69.000000      2.428440e+05      0.424000      0.748000
# max         100.000000      1.799346e+06      0.996000      0.987000
#
#              energy  instrumentalness           key      liveness  \
# count  18835.000000      18835.000000  18835.000000  18835.000000
# mean       0.644995          0.078008      5.289196      0.179650
# std        0.214101          0.221591      3.614595      0.143984
# min        0.001070          0.000000      0.000000      0.010900
# 25%        0.510000          0.000000      2.000000      0.092900
# 50%        0.674000          0.000011      5.000000      0.122000
# 75%        0.815000          0.002570      8.000000      0.221000
# max        0.999000          0.997000     11.000000      0.986000
#
#            loudness    audio_mode   speechiness         tempo  time_signature  \
# count  18835.000000  18835.000000  18835.000000  18835.000000    18835.000000
# mean      -7.447435      0.628139      0.102099    121.073154        3.959119
# std        3.827831      0.483314      0.104378     28.714456        0.298533
# min      -38.768000      0.000000      0.000000      0.000000        0.000000
# 25%       -9.044000      0.000000      0.037800     98.368000        4.000000
# 50%       -6.555000      1.000000      0.055500    120.013000        4.000000
# 75%       -4.908000      1.000000      0.119000    139.931000        4.000000
# max        1.585000      1.000000      0.941000    242.318000        5.000000
#
#        audio_valence
# count   18835.000000
# mean        0.527967
# std         0.244632
# min         0.000000
# 25%         0.335000
# 50%         0.527000
# 75%         0.725000
# max         0.984000

# %%
# Display the shape of the DataFrame
df.shape
# Out:
# (18835, 15)

# %%
# Display info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18835 entries, 0 to 18834
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   song_name         18835 non-null  object
#  1   song_popularity   18835 non-null  int64
#  2   song_duration_ms  18835 non-null  int64
#  3   acousticness      18835 non-null  float64
#  4   danceability      18835 non-null  float64
#  5   energy            18835 non-null  float64
#  6   instrumentalness  18835 non-null  float64
#  7   key               18835 non-null  int64
#  8   liveness          18835 non-null  float64
#  9   loudness          18835 non-null  float64
#  10  audio_mode        18835 non-null  int64
#  11  speechiness       18835 non-null  float64
#  12  tempo             18835 non-null  float64
#  13  time_signature    18835 non-null  int64
#  14  audio_valence     18835 non-null  float64
# dtypes: float64(9), int64(5), object(1)
# memory usage: 2.2+ MB

# %%
# Keep only numerical columns int64 and float64
df = df.select_dtypes(include=['int64', 'float64'])

# %%
# Check for missing values
df.isnull().sum()
# Out:
# song_popularity     0
# song_duration_ms    0
# acousticness        0
# danceability        0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# audio_mode          0
# speechiness         0
# tempo               0
# time_signature      0
# audio_valence       0
# dtype: int64

# %%
# Check data types
df.dtypes
# Out:
# song_popularity       int64
# song_duration_ms      int64
# acousticness        float64
# danceability        float64
# energy              float64
# instrumentalness    float64
# key                   int64
# liveness            float64
# loudness            float64
# audio_mode            int64
# speechiness         float64
# tempo               float64
# time_signature        int64
# audio_valence       float64
# dtype: object

# %%
#Checking number of unique rows in each feature
df.nunique().sort_values()
# Out:
# audio_mode              2
# time_signature          5
# key                    12
# song_popularity       101
# danceability          849
# energy               1132
# speechiness          1224
# audio_valence        1246
# liveness             1425
# acousticness         3209
# instrumentalness     3925
# loudness             8416
# song_duration_ms    11771
# tempo               12112
# dtype: int64

# %%
# Display the columns
df.hist(figsize=(10, 8))
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Dataset analysis

# %%
# Print the correlation matrix chart
corr = df.corr()

plt.figure(figsize=(12, 10))
sns.heatmap(corr, annot=True)
plt.show()

# %%
features = [col for col in df.columns if col != 'song_popularity']

num_rows = (len(features) + 3) // 3
num_cols = min(len(features), 3)    

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20, 5*num_rows))

# Flatten axes if necessary
if num_rows == 1:
    axes = axes.reshape(1, -1)
elif num_cols == 1:
    axes = axes.reshape(-1, 1)

# Plot each feature against song_popularity
for i, column in enumerate(features):
    row = i // num_cols
    col = i % num_cols
    sns.scatterplot(data=df, y=column, x='song_popularity', ax=axes[row, col])
    axes[row, col].set_title(f'{column} vs song_popularity')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Find the correlation values with the target variable

threshold = 0.08

correlation_with_target = abs(corr['song_popularity'])

useful_features = correlation_with_target[correlation_with_target > threshold].index.tolist()

df = df.drop(columns=[col for col in df.columns if col not in useful_features])

print("Useful features:", df.columns.tolist())
# Out:
# Useful features: ['song_popularity', 'danceability', 'instrumentalness', 'loudness']

# %%
# Train a GridSearchCV model

from sklearn.model_selection import train_test_split

X = df.drop(columns='song_popularity')
y = df['song_popularity']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Train a predictive model

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_estimators': [50, 100, 150],
    'max_depth': [5, 10, 15, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

model = RandomForestRegressor()

grid_search = GridSearchCV(model, param_grid, cv=5, n_jobs=-1)


grid_search.fit(X_train, y_train)

# Print the best parameters
print(grid_search.best_params_)

# Print the best score

print(grid_search.best_score_)

# Print the best estimator

print(grid_search.best_estimator_)

# Evaluate the model

from sklearn.metrics import mean_squared_error

y_pred = grid_search.predict(X_test)

mse = mean_squared_error(y_test, y_pred)

print("Mean Squared Error:", mse)
# Out:
# {'max_depth': 20, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# 0.26722456613266327
# RandomForestRegressor(max_depth=20)
# Mean Squared Error: 326.5406215268667

# %%
# Show predictions vs actual values

plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_test, y=y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs Predicted Values")
plt.show()

# %%
# Plot the residuals

residuals = y_test - y_pred

plt.figure(figsize=(10, 6))
sns.scatterplot(x=y_pred, y=residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residuals vs Predicted Values")
plt.axhline(y=0, color='r', linestyle='--')
plt.show()

# %%
# Use lazy predict to evaluate the model

from lazypredict import LazyRegressor

reg = LazyRegressor(verbose=0, ignore_warnings=False, custom_metric=None)

models, predictions = reg.fit(X_train, X_test, y_train, y_test)

print(models)
# Out:
#  21%|██▏       | 9/42 [00:02<00:12,  2.68it/s]
# GammaRegressor model failed to execute
# Some value(s) of y are out of the valid range of the loss 'HalfGammaLoss'.
#  98%|█████████▊| 41/42 [00:56<00:01,  1.08s/it]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000332 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 765
# [LightGBM] [Info] Number of data points in the train set: 15068, number of used features: 3
# [LightGBM] [Info] Start training from score 52.914388
# 100%|██████████| 42/42 [00:57<00:00,  1.36s/it]
#                                Adjusted R-Squared  R-Squared    RMSE  \
# Model
# ExtraTreesRegressor                          0.33       0.33   17.94
# RandomForestRegressor                        0.31       0.31   18.10
# BaggingRegressor                             0.25       0.25   18.88
# XGBRegressor                                 0.17       0.17   19.92
# LGBMRegressor                                0.13       0.13   20.43
# HistGradientBoostingRegressor                0.12       0.13   20.43
# GradientBoostingRegressor                    0.08       0.09   20.90
# KNeighborsRegressor                          0.08       0.08   20.94
# MLPRegressor                                 0.05       0.05   21.28
# NuSVR                                        0.05       0.05   21.32
# AdaBoostRegressor                            0.03       0.03   21.48
# SVR                                          0.03       0.03   21.48
# PoissonRegressor                             0.03       0.03   21.52
# LassoLarsCV                                  0.03       0.03   21.54
# LinearRegression                             0.03       0.03   21.54
# OrthogonalMatchingPursuitCV                  0.03       0.03   21.54
# TransformedTargetRegressor                   0.03       0.03   21.54
# LassoLarsIC                                  0.03       0.03   21.54
# LarsCV                                       0.03       0.03   21.54
# Lars                                         0.03       0.03   21.54
# Ridge                                        0.03       0.03   21.54
# RidgeCV                                      0.03       0.03   21.54
# LassoCV                                      0.03       0.03   21.54
# BayesianRidge                                0.03       0.03   21.54
# ElasticNetCV                                 0.03       0.03   21.54
# SGDRegressor                                 0.03       0.03   21.55
# Lasso                                        0.02       0.02   21.60
# LassoLars                                    0.02       0.02   21.60
# ElasticNet                                   0.02       0.02   21.60
# TweedieRegressor                             0.02       0.02   21.61
# HuberRegressor                               0.02       0.02   21.63
# OrthogonalMatchingPursuit                    0.02       0.02   21.64
# LinearSVR                                    0.01       0.01   21.70
# DummyRegressor                              -0.00      -0.00   21.85
# QuantileRegressor                           -0.01      -0.01   21.92
# PassiveAggressiveRegressor                  -0.09      -0.09   22.82
# ExtraTreeRegressor                          -0.17      -0.17   23.64
# DecisionTreeRegressor                       -0.18      -0.18   23.71
# RANSACRegressor                             -0.32      -0.32   25.09
# KernelRidge                                 -5.91      -5.90   57.41
# GaussianProcessRegressor                 -3443.66   -3440.91 1281.90
#
#                                Time Taken
# Model
# ExtraTreesRegressor                  1.23
# RandomForestRegressor                3.05
# BaggingRegressor                     0.30
# XGBRegressor                         0.36
# LGBMRegressor                        0.66
# HistGradientBoostingRegressor        0.90
# GradientBoostingRegressor            0.87
# KNeighborsRegressor                  0.03
# MLPRegressor                         6.90
# NuSVR                                4.85
# AdaBoostRegressor                    0.09
# SVR                                  5.50
# PoissonRegressor                     0.20
# LassoLarsCV                          0.01
# LinearRegression                     0.02
# OrthogonalMatchingPursuitCV          0.17
# TransformedTargetRegressor           0.01
# LassoLarsIC                          0.04
# LarsCV                               0.02
# Lars                                 0.02
# Ridge                                0.01
# RidgeCV                              0.06
# LassoCV                              0.26
# BayesianRidge                        0.07
# ElasticNetCV                         0.26
# SGDRegressor                         0.05
# Lasso                                0.28
# LassoLars                            0.01
# ElasticNet                           0.14
# TweedieRegressor                     0.15
# HuberRegressor                       0.04
# OrthogonalMatchingPursuit            0.01
# LinearSVR                            0.04
# DummyRegressor                       0.01
# QuantileRegressor                    3.74
# PassiveAggressiveRegressor           0.05
# ExtraTreeRegressor                   0.04
# DecisionTreeRegressor                0.09
# RANSACRegressor                      0.07
# KernelRidge                          8.81
# GaussianProcessRegressor            17.62

# %%
# Remove GaussianProcessRegressor and KernelRidge
models = models.drop(index=['GaussianProcessRegressor', 'KernelRidge'])

# Plot the R-squared values

plt.figure(figsize=(10, 6))
sns.barplot(x=models.index, y=models['R-Squared'])
plt.xticks(rotation=90)
plt.ylabel("R-Squared")
plt.title("Model R-Squared Values")
plt.show()
